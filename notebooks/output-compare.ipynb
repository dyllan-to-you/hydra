# %%
import pandas as pd
from pathlib import Path
import json
pd.set_option('display.max_columns', None)
pd.reset_option('display.max_columns')
pd.set_option('display.max_colwidth', 0)

pd.set_option('display.max_rows', None)

outputDir = Path('../output')

def parse(output):
    split = output.split()
    file1 = outputDir / split[1]
    file2 = outputDir / split[3]
    return file1, file2

def strip_dupes(df, index=True):
    if index is True:
        index = ['figname']
    df = df.reset_index().set_index(index)
    return df[~df.index.duplicated(keep="first")]

def ld(file, dedup=False, sort=False, save=False):
    df = pd.read_parquet(file)
    # print(df)
    if dedup:
        df = strip_dupes(df, dedup)
    if sort:
        df = df.sort_index()
    if save:
        df.to_parquet(file)
    return df

def load(file1, file2, dedup=False, sort=False, save=False):
    return ld(file1, dedup, sort, save), ld(file2, dedup, sort, save)

def compare(df1, df2, reset_index=False):
    # if len(df1) > len(df2):
    #     return df1.loc[df1.index.difference(df2.index)]
    # elif len(df1) < len(df2):
    #     return df2.loc[df2.index.difference(df1.index)]

    if reset_index:
        df1 = df1.reset_index()
        df2 = df2.reset_index()
    return df1.compare(df2)

# %%
import subprocess

loc = "7-14"
chunky = outputDir/f"enviro-chunky-{loc}"
origin = outputDir/f"enviro-origin-{loc}"

# %%
# print()
out = ld(chunky / 'year=2018' / 'month=1' / 'day=1' / '240.parq')
print(out.columns)
out
# Out:
# Index(['frequency', 'variance', 'amplitude', 'amplitude_normalized',
#        'minPerCycle', 'deviance', 'ifft_extrapolated_wavelength',
#        'ifft_extrapolated_amplitude', 'ifft_extrapolated_deviance',
#        'first_extrapolated', 'first_extrapolated_date',
#        'first_extrapolated_isup', 'startDate', 'endDate', 'window',
#        'window_original', 'trend_deviance', 'trend_slope', 'trend_intercept',
#        'year', 'month', 'day', 'rootNumber'],
#       dtype='object')
#                                                                      frequency  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  0.0
#
#                                                                      variance  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  0.0
#
#                                                                      amplitude  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  0.0
#
#                                                                      amplitude_normalized  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  0.0
#
#                                                                      minPerCycle  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  0.0
#
#                                                                      deviance  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  0.0
#
#                                                                      ifft_extrapolated_wavelength  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  0.0
#
#                                                                      ifft_extrapolated_amplitude  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  0.0
#
#                                                                      ifft_extrapolated_deviance  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  0.0
#
#                                                                      first_extrapolated  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  13766.375029
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  13783.735772
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  13797.484553
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  13815.727758
#
#                                                                      ...  \
# figname                                                              ...
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  ...
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  ...
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  ...
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  ...
#
#                                                                                 endDate  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0 2018-01-01 09:15:00
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0 2018-01-01 09:17:00
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0 2018-01-01 09:19:00
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0 2018-01-01 09:21:00
#
#                                                                      window  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  42.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  42.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  42.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  42.0
#
#                                                                     window_original  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  42.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  42.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  42.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  42.0
#
#                                                                     trend_deviance  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  0.006679
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.004837
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.005073
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  0.005797
#
#                                                                      trend_slope  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0 -0.900276
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  0.124698
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  0.839259
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  1.631634
#
#                                                                      trend_intercept  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  13804.186600
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  13778.498450
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  13762.235659
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  13747.199114
#
#                                                                      year  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  2018
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  2018
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  2018
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  2018
#
#                                                                      month  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  1
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  1
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  1
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  1
#
#                                                                      day  \
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  1
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  1
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  1
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  1
#
#                                                                      rootNumber
# figname
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15|p0 days 00:42:00|c0.0  240
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17|p0 days 00:42:00|c0.0  240
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19|p0 days 00:42:00|c0.0  240
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21|p0 days 00:42:00|c0.0  240
#
# [4 rows x 23 columns]

# %%
ld(chunky / 'year=2018' / 'month=1' / 'day=1' / '240.xtrp.parq')
# Out:
#                                                         startDate  \
# index
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15 2018-01-01 08:34:00
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17 2018-01-01 08:36:00
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19 2018-01-01 08:38:00
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21 2018-01-01 08:40:00
#
#                                                           endDate  window  \
# index
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15 2018-01-01 09:15:00  42.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17 2018-01-01 09:17:00  42.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19 2018-01-01 09:19:00  42.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21 2018-01-01 09:21:00  42.0
#
#                                                window_original  \
# index
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15  42.0
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17  42.0
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19  42.0
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21  42.0
#
#                                               significant_dates  \
# index
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15  []
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17  []
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19  []
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21  []
#
#                                               significant_values  \
# index
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15  []
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17  []
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19  []
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21  []
#
#                                                         insignificant_dates  \
# index
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15  [2018-01-01T09:36:00.000000]
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17  [2018-01-01T09:37:00.000000]
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19  [2018-01-01T09:38:00.000000]
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21  [2018-01-01T09:40:00.000000]
#
#                                                insignificant_values  year  \
# index
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15  [13689.406793211203]  2018
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17  [13737.292199452138]  2018
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19  [13771.42763754803]   2018
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21  [13810.1604609877]    2018
#
#                                                month  day  rootNumber
# index
# (D)BTCUSD 2018-01-01 08:34 - 2018-01-01 09:15  1      1    240
# (D)BTCUSD 2018-01-01 08:36 - 2018-01-01 09:17  1      1    240
# (D)BTCUSD 2018-01-01 08:38 - 2018-01-01 09:19  1      1    240
# (D)BTCUSD 2018-01-01 08:40 - 2018-01-01 09:21  1      1    240

# %%
# Compare accumulated parents
ap_fn = "accumulated_parents.parq"
ap_chunky, ap_origin = load(chunky/ap_fn, origin/ap_fn, dedup=True, sort=True, save=False)
print(len(ap_chunky), len(strip_dupes(ap_chunky)), len(ap_origin), len(strip_dupes(ap_origin)))
compare(ap_chunky, ap_origin)
# ld(chunky/ap_fn)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_66261/1550700268.py in <module>
#       1 # Compare accumulated parents
#       2 ap_fn = "accumulated_parents.parq"
# ----> 3 ap_chunky, ap_origin = load(chunky/ap_fn, origin/ap_fn, dedup=True, sort=True, save=False)
#       4 print(len(ap_chunky), len(strip_dupes(ap_chunky)), len(ap_origin), len(strip_dupes(ap_origin)))
#       5 compare(ap_chunky, ap_origin)
#
# /tmp/ipykernel_66261/1241969442.py in load(file1, file2, dedup, sort, save)
#      34
#      35 def load(file1, file2, dedup=False, sort=False, save=False):
# ---> 36     return ld(file1, dedup, sort, save), ld(file2, dedup, sort, save)
#      37
#      38 def compare(df1, df2, reset_index=False):
#
# /tmp/ipykernel_66261/1241969442.py in ld(file, dedup, sort, save)
#      23
#      24 def ld(file, dedup=False, sort=False, save=False):
# ---> 25     df = pd.read_parquet(file)
#      26     # print(df)
#      27     if dedup:
#
# ~/.cache/pypoetry/virtualenvs/hydra-Qraj0X5q-py3.8/lib/python3.8/site-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, use_nullable_dtypes, **kwargs)
#     457     """
#     458     impl = get_engine(engine)
# --> 459     return impl.read(
#     460         path, columns=columns, use_nullable_dtypes=use_nullable_dtypes, **kwargs
#     461     )
#
# ~/.cache/pypoetry/virtualenvs/hydra-Qraj0X5q-py3.8/lib/python3.8/site-packages/pandas/io/parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     212                 )
#     213
# --> 214         path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     215             path,
#     216             kwargs.pop("filesystem", None),
#
# ~/.cache/pypoetry/virtualenvs/hydra-Qraj0X5q-py3.8/lib/python3.8/site-packages/pandas/io/parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#      80         # fsspec resources can also point to directories
#      81         # this branch is used for example when reading from non-fsspec URLs
# ---> 82         handles = get_handle(path_or_handle, mode, is_text=False)
#      83         fs = None
#      84         path_or_handle = handles.handle
#
# ~/.cache/pypoetry/virtualenvs/hydra-Qraj0X5q-py3.8/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output/enviro-origin-7-14/accumulated_parents.parq'

# %%
output = subprocess.run(["diff", "-qr", chunky, origin], capture_output=True, text=True)
strings = output.stdout.split('\n')

# Compare results
anomalies = 0
diff = 0
onlyIn = []

differences = [s for s in strings if len(s) and not 'xtrp' in s and not 'accumulated' in s]
for string in differences:
    if 'Only in' in string:
        onlyIn.append(string)
        anomalies +=1
        continue
    try:
        df1, df2 = load(*parse(string), dedup=True, sort=True, save=False)
        if not df1.equals(df2):
            anomalies+=1
            diff +=1
            print(f"{string} ({len(df1)=} {len(df2)=})")
            # if len(df1) == len(df2):
            #     cmp = compare(df1, df2)
            #     # print(cmp)
            #     print(df1, df2)   
            # assert df1.equals(df2), string
    except Exception as err:
        print(string)
        print(err)
        anomalies+=1
print(anomalies, diff, len(onlyIn))
print(onlyIn)
# Out:
# 0 0 0
# []
